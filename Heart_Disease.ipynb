# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/heart.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.columns = ['Age', 'Gender', 'ChestPain', 'RestingBloodPressure', 'Cholesterol', 'FastingBloodSugar', 'RestingECG', 'MaxHeartRateAchieved', 'ExerciseInducedAngina', 'OldPeak', 'Slope', 'MajorVessels', 'Thalassemia', 'Target']

# %%
df.head()
df['Thalassemia'].value_counts()
# Out:
# 2    544
# 3    410
# 1     64
# 0      7
# Name: Thalassemia, dtype: int64

# %%
sns.countplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
result='ExcerciseInducedAngina'

# %%
a=sns.countplot(hue=result, x='MajorVessels',data=df)

# %%
result="ChestPain"

# %%
a=sns.countplot(hue=result, x='Gender',data=df)

# %%
sns.regplot(x='RestingBloodPressure', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='RestingBloodPressure', ylabel='Cholesterol'>

# %%
j=[]
for i in df['RestingBloodPressure']:
  if i>130:
    j.append(1)
  else:
    j.append(0)
sns.countplot(x=j)
# Out:
# <Axes: ylabel='count'>

# %%
k=[]
for i in df['Cholesterol']:
  if i<=200:
    k.append(1)
  else:
    k.append(0)
sns.countplot(x=k)
# Out:
# <Axes: ylabel='count'>

# %%
m=[]
for i in df['Thalassemia']:
  if i>=9.5:
    m.append(1)
  else:
    m.append(0)
sns.countplot(x=m)
# Out:
# <Axes: ylabel='count'>

# %%
l=[]
for i in df['MaxHeartRateAchieved']:
  if i>100:
    l.append(1)
  else:
    l.append(0)
sns.countplot(x=l)
# Out:
# <Axes: ylabel='count'>
